# %%
#from https://towardsdatascience.com/topic-modeling-with-bert-779f7db187e6
import pandas as pd
from sklearn.datasets import fetch_20newsgroups
from sklearn.metrics.pairwise import cosine_similarity

# %%
import os

data = []
names = []
for root, dirs, files in os.walk("../../data/2_raw_text"):
    print(f"-Dir: {root}")
    for dir in dirs:
        print(f"--{dir}")
    for filename in files:
        print(f"---{filename}")
        with open(f"{root}/{filename}") as f:
            data.append(f.read())
            names.append(filename)
# Out:
# -Dir: ../../data/2_raw_text
# ---1037_text.txt
# ---801_text.txt
# ---1348_text.txt
# ---1269_text.txt
# ---842_text.txt
# ---625_text.txt
# ---305_text.txt
# ---1159_text.txt
# ---1182_text.txt
# ---1122_text.txt
# ---674_text.txt
# ---312_text.txt
# ---216_text.txt
# ---1921_text.txt
# ---428_text.txt
# ---589_text.txt
# ---204_text.txt
# ---1487_text.txt
# ---1529_text.txt
# ---1468_text.txt
# ---1436_text.txt
# ---68_text.txt
# ---1899_text.txt
# ---1563_text.txt
# ---1107_text.txt
# ---1435_text.txt
# ---1151_text.txt
# ---951_text.txt
# ---85_text.txt
# ---661_text.txt
# ---503_text.txt
# ---878_text.txt
# ---989_text.txt
# ---897_text.txt
# ---86_text.txt
# ---1108_text.txt
# ---648_text.txt
# ---1559_text.txt
# ---752_text.txt
# ---1539_text.txt
# ---197_text.txt
# ---436_text.txt
# ---244_text.txt
# ---1231_text.txt
# ---441_text.txt
# ---311_text.txt
# ---297_text.txt
# ---156_text.txt
# ---905_text.txt
# ---1379_text.txt
# ---1320_text.txt
# ---869_text.txt
# ...

# %%
print(len(data))
# Out:
# 1595

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('distilbert-base-nli-mean-tokens')
embeddings = model.encode(data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
import umap
umap_embeddings = umap.UMAP(n_neighbors=3, 
                            n_components=5, 
                            metric='cosine').fit_transform(embeddings)

# %%
import hdbscan
cluster = hdbscan.HDBSCAN(min_cluster_size=3,
                          metric='euclidean',                      
                          cluster_selection_method='eom').fit(umap_embeddings)

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Prepare data
umap_data = umap.UMAP(n_neighbors=15, n_components=2, min_dist=0.0, metric='cosine').fit_transform(embeddings)
result = pd.DataFrame(umap_data, columns=['x', 'y'])
result['labels'] = cluster.labels_

# Visualize clusters
fig, ax = plt.subplots(figsize=(20, 10))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y, color='#BDBDBD', s=0.05)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=0.05, cmap='hsv_r')
plt.colorbar()

print(result)
# Out:
#              x          y  labels
# 0     5.390727   7.570811      -1
# 1     6.122185   8.572335     130
# 2     3.888180  12.215355       7
# 3     8.011756   8.093386     109
# 4    -8.144327   9.244592       3
# ...        ...        ...     ...
# 1590 -8.102684   9.281013       2
# 1591  5.981391   2.393463      42
# 1592  4.478577   7.327545     144
# 1593  6.384166   2.591359      95
# 1594  5.588795   7.689439      -1
#
# [1595 rows x 3 columns]

# %%
docs_df = pd.DataFrame(data, columns=["Doc"])
docs_df['Topic'] = cluster.labels_
docs_df['Doc_ID'] = range(len(docs_df))
docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})

# %%
docs_df["Number"] = [i.split("_")[0] for i in names]
docs_df["Name"] = names

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

def c_tf_idf(documents, m, ngram_range=(1, 1)):
    count = CountVectorizer(ngram_range=ngram_range, stop_words="english").fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count
  
tf_idf, count = c_tf_idf(docs_per_topic.Doc.values, m=len(data))

# %%
def extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20):
    words = count.get_feature_names()
    labels = list(docs_per_topic.Topic)
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    return top_n_words

def extract_topic_sizes(df):
    topic_sizes = (df.groupby(['Topic'])
                     .Doc
                     .count()
                     .reset_index()
                     .rename({"Topic": "Topic", "Doc": "Size"}, axis='columns')
                     .sort_values("Size", ascending=False))
    return topic_sizes

top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=5)
topic_sizes = extract_topic_sizes(docs_df); topic_sizes.head(10)
# Out:
#      Topic  Size
# 0       -1   264
# 114    113    32
# 52      51    28
# 22      21    27
# 87      86    23
# 148    147    18
# 8        7    18
# 115    114    17
# 34      33    17
# 11      10    16

# %%
# Out:
#                                                     Doc  Topic  Doc_ID Number  \
# 46    \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114      46    297
# 60    \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114      60    465
# 73    \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114      73    421
# 78    \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114      78    487
# 163   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114     163   1282
# 243   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114     243   1139
# 344   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114     344    783
# 371   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114     371    784
# 558   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114     558    932
# 603   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114     603   1551
# 713   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    114     713   1309
# ...

# %%
docs_df.sort_values(by=['Topic'])
# Out:
#                                                     Doc  Topic  Doc_ID Number  \
# 0     \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     -1       0   1037
# 710   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     -1     710   1058
# 707   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     -1     707   1035
# 700   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     -1     700    298
# 697   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     -1     697    387
# ...                                                 ...    ...     ...    ...
# 935   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    159     935   1134
# 737   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    159     737    923
# 545   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    159     545   1096
# 1110  \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    159    1110    729
# 1176  \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...    159    1176   1135
#
#                Name
# ...

# %%
for i in range(90):
    print(i)
    # Calculate cosine similarity
    similarities = cosine_similarity(tf_idf.T)
    np.fill_diagonal(similarities, 0)

    # Extract label to merge into and from where
    topic_sizes = docs_df.groupby(['Topic']).count().sort_values("Doc", ascending=False).reset_index()
    topic_to_merge = topic_sizes.iloc[-1].Topic
    topic_to_merge_into = np.argmax(similarities[topic_to_merge + 1]) - 1

    # Adjust topics
    docs_df.loc[docs_df.Topic == topic_to_merge, "Topic"] = topic_to_merge_into
    old_topics = docs_df.sort_values("Topic").Topic.unique()
    map_topics = {old_topic: index - 1 for index, old_topic in enumerate(old_topics)}
    docs_df.Topic = docs_df.Topic.map(map_topics)
    docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})

    # Calculate new topic words
    m = len(data)
    tf_idf, count = c_tf_idf(docs_per_topic.Doc.values, m)
    top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20)
    print(len(top_n_words))
# Out:
# 0
# 160
# 1
# 159
# 2
# 158
# 3
# 157
# 4
# 156
# 5
# 155
# 6
# 154
# 7
# 153
# 8
# 152
# 9
# 151
# 10
# 150
# 11
# 149
# 12
# 148
# 13
# 147
# 14
# 146
# 15
# 145
# 16
# 144
# 17
# 143
# 18
# 142
# 19
# 141
# 20
# 140
# 21
# 139
# 22
# 138
# 23
# 137
# 24
# 136
# 25
# 135
# 26
# 134
# 27
# 133
# 28
# 132
# 29
# 131
# 30
# 130
# 31
# 129
# 32
# 128
# 33
# 127
# 34
# 126
# 35
# 125
# 36
# 124
# 37
# 123
# 38
# 122
# 39
# 121
# 40
# 120
# 41
# 119
# 42
# 118
# 43
# 117
# 44
# 116
# 45
# 115
# 46
# 114
# 47
# 113
# 48
# 112
# 49
# 111
# 50
# 110
# 51
# 109
# 52
# 108
# 53
# 107
# 54
# 106
# 55
# 105
# 56
# 104
# 57
# 103
# 58
# 102
# 59
# 101
# 60
# 100
# 61
# 99
# 62
# 98
# 63
# 97
# 64
# 96
# 65
# 95
# 66
# 94
# 67
# 93
# 68
# 92
# 69
# 91
# 70
# 90
# 71
# 89
# 72
# 88
# 73
# 87
# 74
# 86
# 75
# 85
# 76
# 84
# 77
# 83
# 78
# 82
# 79
# 81
# 80
# 80
# 81
# 79
# 82
# 78
# 83
# 77
# 84
# 76
# 85
# 75
# 86
# 74
# 87
# 73
# 88
# 72
# 89
# 71

# %%
topic_sizes = extract_topic_sizes(docs_df); topic_sizes.head(10)
# Out:
#     Topic  Size
# 0      -1   477
# 65     64    54
# 37     36    53
# 35     34    47
# 48     47    32
# 25     24    28
# 11     10    27
# 12     11    27
# 6       5    27
# 53     52    23

# %%
topics = [64, 36, 34, 47, 24, 10, 11, 5, 52]
for i in topics:
    print(i)
    print(top_n_words[i][0:10])
# Out:
# 64
# [('china', 0.00827347800713072), ('taiwan', 0.0076580732604282905), ('seniors', 0.005700211768350348), ('republic', 0.005254668912303426), ('chinese', 0.005004611523965558), ('ginsburg', 0.0042895883467699665), ('iran', 0.004273016224100284), ('sanctions', 0.00422994582829915), ('saudi', 0.003831428907135868), ('communist', 0.0037789605166336057)]
# 36
# [('behavioral', 0.004987605534949417), ('mental', 0.0048618803384981235), ('tracing', 0.004262002252819216), ('nmosd', 0.0035589190424689804), ('history', 0.003443766065351681), ('suicide', 0.0033305439970151797), ('substance', 0.0032601959888192973), ('contact', 0.002788772975239367), ('ethnic', 0.0027013986528209165), ('territorial', 0.002559063715431906)]
# 34
# ...

# %%
bytopic = docs_df['Topic']==64
docs_df[bytopic]
# Out:
#                                                     Doc  Topic  Doc_ID Number  \
# 75    \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64      75   1169
# 110   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     110    857
# 164   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     164    481
# 183   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     183   1149
# 263   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     263    852
# 270   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     270   1322
# 292   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     292    289
# 317   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     317    875
# 320   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     320    938
# 321   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     321    339
# 352   \n\n\n\n\n\n\n117th CONGRESS\n  1st Session\n ...     64     352    591
# ...

# %%
doc_num = 1128
print(docs_df['Doc'][doc_num])
# Out:
# 117th CONGRESS
#   1st Session
#                                 H. R. 992
#
#   To direct the Attorney General to report to Congress on how United
#   States taxpayer-funded research has benefitted China, and for other
#                                purposes.
#
#
# _______________________________________________________________________
#
#
#                     IN THE HOUSE OF REPRESENTATIVES
#
#                            February 11, 2021
#
#  Mr. Good of Virginia (for himself, Ms. Herrell, Mr. Hice of Georgia,
#  Mr. Gohmert, and Mr. Baird) introduced the following bill; which was
#   referred to the Committee on Science, Space, and Technology, and in
#    addition to the Committee on Foreign Affairs, for a period to be
# subsequently determined by the Speaker, in each case for consideration
#   of such provisions as fall within the jurisdiction of the committee
#                                concerned
#
# ...

# %%
print(docs_df["Topic"][doc_num])
print(top_n_words[docs_df["Topic"][doc_num]])
# Out:
# 114
# [('eating', 0.01994199102500873), ('meat', 0.014509263434018984), ('nutrition', 0.013493412201009112), ('food', 0.01182113922830379), ('store', 0.010490453203964207)]

# %%
# 	Topic	Size
# 0	-1	264
# 114	113	32
# 52	51	28
# 22	21	27
# 87	86	23
# 148	147	18
# 8	7	18
# 115	114	17
# 34	33	17
# 11	10	16

print("113:", top_n_words[113])
print("51:", top_n_words[51])
print("21:", top_n_words[21])
print("86:", top_n_words[86])
print("147:", top_n_words[147])
print("18:", top_n_words[18])
print("114:", top_n_words[114])
print("33:", top_n_words[33])
print("10:", top_n_words[10])
# Out:
# 113: [('admission', 0.009952158890147667), ('corridor', 0.007870513953397827), ('union', 0.007631909872217833), ('said', 0.007382217468318122), ('athlete', 0.007284634040427082)]
# 51: [('corruption', 0.010456858006076628), ('boost', 0.006750875926926755), ('abortion', 0.006486452004626026), ('anti', 0.006213495336944084), ('startups', 0.0058679667291769684)]
# 21: [('religious', 0.014206675298710085), ('xinjiang', 0.011609703258052427), ('uyghur', 0.011419380253822059), ('autonomous', 0.011231177346330452), ('forced', 0.00803447888916621)]
# 86: [('nmosd', 0.009053575641647355), ('mental', 0.008995050234475685), ('behavioral', 0.00869628876164292), ('history', 0.00847803545875853), ('tracing', 0.007839713679933094)]
# 147: [('taiwan', 0.015928717219641914), ('china', 0.014197221268511561), ('seniors', 0.013973596055611886), ('fraud', 0.008543770594490517), ('republic', 0.007813298929899105)]
# ...

# %%
df2 = docs_df.drop("Doc",axis=1)
df2 = df2.drop("Doc_ID",axis=1)
# df2 = df2.set_index("Doc_Name")
print(df2)
# Out:
#       Topic Number           Name
# 0        -1   1037  1037_text.txt
# 1       130    801   801_text.txt
# 2         7   1348  1348_text.txt
# 3       109   1269  1269_text.txt
# 4         3    842   842_text.txt
# ...     ...    ...            ...
# 1590      2   1762  1762_text.txt
# 1591     42     75    75_text.txt
# 1592    144    711   711_text.txt
# 1593     95    196   196_text.txt
# 1594     -1    212   212_text.txt
#
# [1595 rows x 3 columns]

# %%
json_data = df2.to_json(orient="split")
import json
parsed = json.loads(json_data)
with open ("../../data/4_clustering/clustering_docs.json", "w") as f:
    json.dump(parsed, f)

# %%
with open ("../../data/4_clustering/topic_map.json", "w") as f:
    json.dump(top_n_words, f)
